# %% [markdown]
# <a href="https://colab.research.google.com/github/Daoooie/MBA66/blob/main/231225_Final_Project_Model_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Library Archive
# ```
# # https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
# import libarchive
# import libarchive
#
# # https://pypi.python.org/pypi/libarchive
# !apt-get -qq install -y libarchive-dev && pip install -U libarchive
# import libarchive
#
# # This only needs to be done once per notebook.
# from pydrive.auth import GoogleAuth
# from pydrive.drive import GoogleDrive
# from google.colab import auth
# from oauth2client.client import GoogleCredentials
#
# # Download a file based on its file ID.
# # A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
# file_id = 'REPLACE_WITH_YOUR_FILE_ID'
# downloaded = drive.CreateFile({'id': file_id})
#
# print('Downloaded content "{}"'.format(downloaded.GetContentString()))
# ```

# %% [markdown]
# # Introduction

# %%
# !pip install PyJWT
import jwt

# %%
# Install GraphViz & PyDot
# https://pypi.python.org/pypi/pydot
# !apt-get -qq install -y graphviz && pip install pydot
import pydot
# Install cartopy
# !pip install cartopy
import cartopy
#Importing a library that is not in Colaboratory
# !pip install jwt
# !pip install matplotlib-venn
# !apt-get -qq install -y libfluidsynth1
# !wget -q --show-progress "https://storage.googleapis.com/inspirit-ai-data-bucket-1/Data/AI%20Scholars/Sessions%201%20-%205/Session%201%20-%20Python%20Basics%20and%20Libraries/tips.csv"
# !touch "/root/.local/share/jupyter/runtime/kernel-74860e1d-8b5a-47e4-8757-c6545e03e4e1.pem"
# Import PyDrive and associated libraries.
# Install 7zip reader libarchive
import pandas as pd
import numpy as np
import time
import sys
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.datasets import fetch_california_housing
data = fetch_california_housing()
# Out:
# ...
# E: Package 'libfluidsynth1' has no installation candidate
# tips.csv.28         100%[===================>]   7.82K  --.-KB/s    in 0s

# %%
# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
GDP = pd.Series([264.50, 250.07, 248.84, 242.83], index = ['Czech Republic', 'Iraq', 'Romania', 'Portugal'])
print(GDP)
# Out:
# Czech Republic    264.50
# Iraq              250.07
# Romania           248.84
# Portugal          242.83
# dtype: float64

# %% [markdown]
# # 1. Initialize Project

# %%
# !/usr/bin/env python3
#from jwt import JWT, jwk_from_pem
import jwt
# jwt_instance = jwt.JWT()

# %% [markdown]
# # 2. Processining Raw Data

# %%
# GDP
GDP = pd.Series([264.50, 250.07, 248.84, 242.83], index = ['Czech Republic', 'Iraq', 'Romania', 'Portugal'])
print(GDP)
# Out:
# Czech Republic    264.50
# Iraq              250.07
# Romania           248.84
# Portugal          242.83
# dtype: float64

# %% [markdown]
# # 3. Training the Model

# %%
# Instructor Solution { display-mode: "form" }
animal_length = [8,6,9,1,8,9,5,6,6,6,5,3,4,5]
animal_weight = [7,13,8,12,11,8,10,14,9,11,10,10,9,14]

plt.scatter(animal_length, animal_weight)
plt.xlabel("Length")
plt.ylabel("Weight")
# Out:
# Text(0, 0.5, 'Weight')

# %%
# Run this code to import the data and read it in using 'pd.read_csv('file')'
tips = pd.read_csv('tips.csv')
ax = sns.scatterplot(x="total_bill", y="tip", data=tips) #plotting it

sns.catplot(x="day", y="total_bill", data=tips);
sns.catplot(x="total_bill", y="day", hue="time", kind="swarm", data=tips);

# %% [markdown]
# # 4. Testing

# %% [markdown]
# # 5. Teach

# %% [markdown]
# # 6. Evaluation

# %% [markdown]
# # 7. Analysis

# %% [markdown]
# # 8. Revise Model

# %% [markdown]
# # 9. Validation

# %% [markdown]
# # 10. Error Report

# %%
# pyjwt in /usr/lib/python3/dist-packages (2.3.0)
pem = '/root/.local/share/jupyter/runtime/kernel-04c66418-0727-481e-818f-f312b83f94f9.pem'
# cannot access
pem = '/root/.local/share/jupyter/runtime/kernel-74860e1d-8b5a-47e4-8757-c6545e03e4e1.pem'
# FileNotFoundError: [Errno 2] No such file or directory: '-f'
# input https://github.com/settings/applications/2422205
# Client ID: fcc1bc5af7779d27d98c
# Client secrets: 9508c3b91a84b6b137f15b422970c47d79fc9d97

# %%
# !pip install PyJWT
import jwt

# %%
# !pip install PyJWT
import os

# %%
# !pip install pyjwt
import jwt

# %%
# Get PEM file path
if len(sys.argv) > 1:
    pem = sys.argv[1]
else:
    pem = input("https://github.com/settings/applications/2422205")
# Get the App ID
if len(sys.argv) > 2:
    app_id = sys.argv[2]
else:
    app_id = input("fcc1bc5af7779d27d98c")
def jwk_from_pem(pem_key):
  """Parses a PEM-encoded JWK key.Args: 9508c3b91a84b6b137f15b422970c47d79fc9d97
  pem_key: 9508c3b91a84b6b137f15b422970c47d79fc9d97
  Returns:
    A JWK object.
"""

# %%
if not pem:
    pem = input("Enter path of private PEM file: ")
# FileNotFoundError: [Errno 2] No such file or directory: '-f'

# %%
# Get PEM file path
if len(sys.argv) > 1:
    pem = sys.argv[1]
else:
    pem = input("9508c3b91a84b6b137f15b422970c47d79fc9d97")

# Check if PEM file exists
if os.path.isfile(pem):

    # Open PEM
    with open(pem, 'rb') as pem_file:
        signing_key = jwk_from_pem(pem_file.read())
else:
    print("PEM file does not exist.")
# Out:
# PEM file does not exist.
